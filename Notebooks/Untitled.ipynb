# %%
import numpy as np
import matplotlib.pyplot as plt

from chainercv import transforms, visualizations
# %matplotlib inline

# %%
np.load('../datasets/moving_mnist_test.npy').shape
# Out:
# (1000, 20, 64, 64)

# %%
np.load('../datasets/moving_mnist_train.npy').shape
# Out:
# (9000, 20, 64, 64)

# %%
np.load('../datasets/sequence_coil_100_test.npy').shape
# Out:
# (10, 72, 64, 64, 3)

# %%
data = np.load('../datasets/sequence_coil_100_test.npy')

# %%
data.shape, data.dtype, data.max()
# Out:
# ((10, 72, 64, 64, 3), dtype('uint8'), 255)

# %%
seq = data[0, [0, 1, 2]].transpose(0, 3, 1, 2).astype(np.float32) / 255

# %%
seq.shape, seq.dtype, seq.max()
# Out:
# ((3, 3, 64, 64), dtype('float32'), 1.0)

# %%
seq_new = np.rot90(seq, axes=(2,3))
visualizations.vis_image(np.clip(seq_new * 255, 0, 255).astype(np.uint8)[0])
visualizations.vis_image(np.clip(seq_new * 255, 0, 255).astype(np.uint8)[1])
visualizations.vis_image(np.clip(seq_new * 255, 0, 255).astype(np.uint8)[2])
